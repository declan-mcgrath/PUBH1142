# %% [markdown]
# # Child Fatality Trends by U.S. State

# %% [markdown]
# > ## Declan McGrath

# %% [markdown]
# ### Introduction

# %% [markdown]
# Child fatality, as one can assume, is measured by the amount of deaths among children under the age of 18. Across the world, infectious diseases, diarrhea, and other health conditions are the leading causes for death among children (The Global Health Observatory, 2024). In the United States, however, most of the child fatalities can be attributed to gun accidents/violence and car accidents (McGough et al., 2023). This makes child fatalities much easier to prevent in the United States compared to other parts of the world, since both are human behaviors that can be changed.
#
# While a public health intervention must materialize at some point to address child fatalities, it should first be analyzed where children are dying the most so that the campaign has a focus. This is made possible with a dataset that contains the total child fatalities from 2015-2019 across all the states, as well as the total child fatalities in the United states in the same timespan.
#
# Before any analysis is performed, a few clarifications must be made about the dataset used. First, there are some states that did not report their child fatalities in a given year. These states include Maine from 2015-2017, Massachusetts from 2017-2019, and North Carolina in 2015. These states are represented with a 0 on Figures 2-6, but they are likely to have had child fatalities during that time.

# %% [markdown]
# ### Data Initialization

# %% [markdown]
# First, the necessary packages must be imported into Python.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# Next, the dataset is read to go by the shorthand of 'df'.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/declan-mcgrath/PUBH1142/main/Child_Fatalities_Trend_20240409.csv")

# %% [markdown]
# ### Data Verification

# %%
df.columns
# Out:
# Index(['State', '2015', '2016', '2017', '2018', '2019'], dtype='object')

# %% [markdown]
# The columns of data are as follows:
# - *State*: the state in which the child fatalities were collected; also includes a row of national data and a row of how many states reported data in each year
# - *2015*: the amount of child fatalities in 2015
# - *2016*: the amount of child fatalities in 2016
# - *2017*: the amount of child fatalities in 2017
# - *2018*: the amount of child fatalities in 2018
# - *2019*: the amount of child fatalities in 2019

# %%
df.head()
# Out:
#         State   2015   2016   2017   2018   2019
# 0     Alabama   13.0   26.0   28.0   43.0   34.0
# 1      Alaska    5.0    1.0    2.0    2.0    1.0
# 2     Arizona   51.0   48.0   35.0   48.0   33.0
# 3    Arkansas   40.0   42.0   37.0   44.0   35.0
# 4  California  127.0  137.0  147.0  145.0  149.0

# %% [markdown]
# The first 5 rows of data were output to confirm that the dataset was loaded correctly.

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# First, the national data of child fatalities in the United States is extracted. With the values from the dataset, a list of the years and child fatalities are created to more easily make a graph.

# %%
national_data = df.iloc[51:52]
national_data
# Out:
#        State    2015    2016    2017    2018    2019
# 51  National  1603.0  1708.0  1677.0  1751.0  1809.0

# %%
years = [2015, 2016, 2017, 2018, 2019]
child_fatalities = [1603, 1708, 1677, 1751, 1809]

# %% [markdown]
# Next, the rows including national statistics and the number of reporting states must be excluded when comparing the amount of child fatalities by year in each state. Therefore, a subdataframe including only the state-level statistics called 'states_df' will be created.

# %%
states_df = df.iloc[:51]

# %%
states_df.tail()
# Out:
#             State  2015  2016  2017  2018  2019
# 46       Virginia  54.0  45.0  41.0  37.0  49.0
# 47     Washington  27.0  15.0  18.0  28.0  25.0
# 48  West Virginia   9.0  20.0  17.0   8.0  17.0
# 49      Wisconsin  17.0  25.0  31.0  24.0  34.0
# 50        Wyoming   2.0   4.0   4.0   1.0   0.0

# %% [markdown]
# The subdataframe 'states_df' is confirmed to have removed the national statistics and number of reporting states with the 'tail' function.

# %% [markdown]
# Before any graphs comparing child fatalities across the states are made, the columns in the state-exclusive subdataframe must be labeled.

# %%
sdf_state = states_df['State']
sdf_twenty_fifteen = states_df['2015']
sdf_twenty_sixteen = states_df['2016']
sdf_twenty_seventeen = states_df['2017']
sdf_twenty_eighteen = states_df['2018']
sdf_twenty_nineteen = states_df['2019']

# %% [markdown]
# ### Data Visualization

# %%
def choose_color(value):
    if value == 2015:
        return 'blue'
    elif value == 2016:
        return 'green'
    elif value == 2017:
        return 'purple'
    elif value == 2018:
        return 'orange'
    else:
        return 'red'

colors = [choose_color(value) for value in years]

plt.bar(years, child_fatalities, color=colors)
plt.title('Figure 1: Child Fatalities by Year in the United States')
plt.xlabel('Year')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# Figure 1 represents the total amount of child fatalities in a given year in the United States.

# %% [markdown]
# Figures 2-6 display the amount of child fatalities in a state during a given year.

# %%
plt.figure(figsize = (10, 6))
plt.bar(sdf_state, sdf_twenty_fifteen, color='blue')
plt.xticks(rotation = 90)
plt.title('Figure 2: Child Fatalities by State: 2015')
plt.xlabel('State')
plt.ylabel('Deaths')
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(sdf_state, sdf_twenty_sixteen, color='green')
plt.xticks(rotation = 90)
plt.title('Figure 3: Child Fatalities by State: 2016')
plt.xlabel('State')
plt.ylabel('Deaths')
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(sdf_state, sdf_twenty_seventeen, color='purple')
plt.xticks(rotation = 90)
plt.title('Figure 4: Child Fatalities by State: 2017')
plt.xlabel('State')
plt.ylabel('Deaths')
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(sdf_state, sdf_twenty_eighteen, color='orange')
plt.xticks(rotation = 90)
plt.title('Figure 5: Child Fatalities by State: 2018')
plt.xlabel('State')
plt.ylabel('Deaths')
plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.bar(sdf_state, sdf_twenty_nineteen, color='red')
plt.xticks(rotation = 90)
plt.title('Figure 6: Child Fatalities by State: 2019')
plt.xlabel('State')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# ### Discussion

# %% [markdown]
# Beginning with the total child fatalities by year in the United States, there is a noticeable trend of increasing deaths over the 5 year period of 2015-2019. There were approximately 200 more child fatalities in 2019 compared to 2015, as represented by Figure 1.
#
# In Figures 2-6, Texas consistently had the most child fatalities. This can be attributed to its high population and lax gun ownership laws. In fact, the leading states in child fatalities have unrestrictive gun laws aside from California and New York. Those two states are at similar levels with the other states because they are some of the most populated states in the country, and also have a lot of traffic that can lead to car accidents.
#
# Ongoing research surrounding child fatalities in the United States should investigate why there is a rising trend in the subject. Ideally, it would determine if it is because of a growing population or if there is a more significant cause that requires addressing. Further research could also look into the effects of gun control on child fatalities. If this research finds that it lessens the amount of children that die in a given state, it can be used as evidence to why the United States needs more restrictive firearm laws. Finally, future research could emphasize the effects the COVID-19 pandemic had on child fatalities since this dataset ends in 2019.

# %% [markdown]
# ### References

# %% [markdown]
# > Child mortality and causes of death. (2024). The Global Health Observatory. https://www.who.int/data/gho/data/themes/topics/topic-details/GHO/child-mortality-and-causes-of-death
#
# > McGough, M., Amin, K., Panchal, N., Cox, C. (2023, July 18). Child and Teen Firearm Mortality in the U.S. and Peer Countries. KFF. https://www.kff.org/mental-health/issue-brief/child-and-teen-firearm-mortality-in-the-u-s-and-peer-countries/
